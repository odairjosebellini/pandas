# %% [markdown]
# https://github.com/tkrabel/bamboolib

# %% [markdown]
# bamboolib demo
# How to get started
# Watch the short demo video: https://www.youtube.com/watch?v=VUkRlt4HieY
#
# Execute all cells and experiment with bamboolib yourself
#
# Interested in using bamboolib on your own data? Get started
#
# Troubleshooting
# If the ipython kernel becomes idle or you see a Connection failed popup, then please launch a new Binder notebook.
# If you have any other problem using bamboolib in this notebook, then please send us an email.

# %%
# !pip install 'numpy>=1.19.0' 'bamboolib>=1.29.1'
# Out:
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.7/dist-packages (1.21.6)
# Collecting bamboolib>=1.29.1
#   Downloading bamboolib-1.30.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (8.2 MB)
#      |████████████████████████████████| 8.2 MB 5.4 MB/s
# Collecting seaborn<0.11,>=0.10
#   Downloading seaborn-0.10.1-py3-none-any.whl (215 kB)
#      |████████████████████████████████| 215 kB 11.2 MB/s
# Collecting ipyslickgrid==0.0.3
#   Downloading ipyslickgrid-0.0.3.tar.gz (51.4 MB)
#      |████████████████████████████████| 51.4 MB 2.0 MB/s
# Requirement already satisfied: psutil<6,>=5.4.2 in /usr/local/lib/python3.7/dist-packages (from bamboolib>=1.29.1) (5.4.8)
# Collecting plotly<5.0.0,>=4.9.0
#   Downloading plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
#      |████████████████████████████████| 13.2 MB 122 kB/s
# Collecting cryptography<3.0.0,>=2.6.1
#   Downloading cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 38.1 MB/s
# Requirement already satisfied: statsmodels<1.0.0 in /usr/local/lib/python3.7/dist-packages (from bamboolib>=1.29.1) (0.10.2)
# Requirement already satisfied: pandas<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from bamboolib>=1.29.1) (1.3.5)
# Collecting toml>=0.10.0
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: jedi<1.0.0 in /usr/local/lib/python3.7/dist-packages (from bamboolib>=1.29.1) (0.18.1)
# Requirement already satisfied: attrs>=20.3.0 in /usr/local/lib/python3.7/dist-packages (from bamboolib>=1.29.1) (21.4.0)
# Requirement already satisfied: scikit-learn<2.0.0,>=0.20.2 in /usr/local/lib/python3.7/dist-packages (from bamboolib>=1.29.1) (1.0.2)
# Requirement already satisfied: packaging>=19.2 in /usr/local/lib/python3.7/dist-packages (from bamboolib>=1.29.1) (21.3)
# Collecting ppscore<2.0.0,>=1.2.0
#   Downloading ppscore-1.2.0.tar.gz (47 kB)
#      |████████████████████████████████| 47 kB 4.2 MB/s
# Requirement already satisfied: ipywidgets<8.0.0,>=7.6.0 in /usr/local/lib/python3.7/dist-packages (from bamboolib>=1.29.1) (7.7.0)
# Collecting analytics-python==1.2.9
#   Downloading analytics_python-1.2.9-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: xlrd>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from bamboolib>=1.29.1) (1.1.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from bamboolib>=1.29.1) (2.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from analytics-python==1.2.9->bamboolib>=1.29.1) (1.15.0)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.7/dist-packages (from analytics-python==1.2.9->bamboolib>=1.29.1) (2.8.2)
# Requirement already satisfied: requests<3.0,>=2.7 in /usr/local/lib/python3.7/dist-packages (from analytics-python==1.2.9->bamboolib>=1.29.1) (2.23.0)
# Requirement already satisfied: notebook>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipyslickgrid==0.0.3->bamboolib>=1.29.1) (5.3.1)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.7/dist-packages (from cryptography<3.0.0,>=2.6.1->bamboolib>=1.29.1) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi!=1.11.3,>=1.8->cryptography<3.0.0,>=2.6.1->bamboolib>=1.29.1) (2.21)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (1.1.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (5.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (4.10.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (5.5.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (3.6.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (5.4.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (5.3.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (5.1.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (4.4.2)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (0.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi<1.0.0->bamboolib>=1.29.1) (0.8.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (4.10.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (2.15.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (5.7.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (0.18.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (4.11.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (4.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (3.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib>=1.29.1) (0.13.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib>=1.29.1) (1.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib>=1.29.1) (5.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib>=1.29.1) (2.11.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (22.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=19.2->bamboolib>=1.29.1) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.1.0->bamboolib>=1.29.1) (2022.1)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Collecting scikit-learn<2.0.0,>=0.20.2
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 1.1 MB/s
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib>=1.29.1) (0.2.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.7->analytics-python==1.2.9->bamboolib>=1.29.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.7->analytics-python==1.2.9->bamboolib>=1.29.1) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.7->analytics-python==1.2.9->bamboolib>=1.29.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.7->analytics-python==1.2.9->bamboolib>=1.29.1) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<2.0.0,>=0.20.2->bamboolib>=1.29.1) (3.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<2.0.0,>=0.20.2->bamboolib>=1.29.1) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<2.0.0,>=0.20.2->bamboolib>=1.29.1) (1.1.0)
# Requirement already satisfied: matplotlib>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from seaborn<0.11,>=0.10->bamboolib>=1.29.1) (3.2.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.2->seaborn<0.11,>=0.10->bamboolib>=1.29.1) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.2->seaborn<0.11,>=0.10->bamboolib>=1.29.1) (0.11.0)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels<1.0.0->bamboolib>=1.29.1) (0.5.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib>=1.29.1) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib>=1.29.1) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib>=1.29.1) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib>=1.29.1) (5.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib>=1.29.1) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib>=1.29.1) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib>=1.29.1) (0.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib>=1.29.1) (0.7.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib>=1.29.1) (0.5.1)
# Building wheels for collected packages: ipyslickgrid, ppscore, retrying
#   Building wheel for ipyslickgrid (setup.py) ... done
#   Created wheel for ipyslickgrid: filename=ipyslickgrid-0.0.3-py2.py3-none-any.whl size=1823285 sha256=8973208c59111231a0068a781122fbe048047aedb0739ec17dd80f72305add80
#   Stored in directory: /root/.cache/pip/wheels/1a/a3/58/9c30cef9afebb4ca9f1e892e9245d676de3c2ae6e214e0781d
#   Building wheel for ppscore (setup.py) ... done
#   Created wheel for ppscore: filename=ppscore-1.2.0-py2.py3-none-any.whl size=13068 sha256=704844bf9f1f40dd04bce84820867839724f32fa999ce3afc8af5a97414431ac
#   Stored in directory: /root/.cache/pip/wheels/d2/3c/58/2ff786414b21713edc6f4fdb54fdee89ac37bca5edd1f60634
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11447 sha256=3c21f5d0c935de90314785b794a1ad9ce271fec7e56551f5c02d89c5c562a7da
#   Stored in directory: /root/.cache/pip/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built ipyslickgrid ppscore retrying
# Installing collected packages: scikit-learn, retrying, toml, seaborn, ppscore, plotly, ipyslickgrid, cryptography, analytics-python, bamboolib
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.24.2 which is incompatible.
# Successfully installed analytics-python-1.2.9 bamboolib-1.30.1 cryptography-2.9.2 ipyslickgrid-0.0.3 plotly-4.14.3 ppscore-1.2.0 retrying-1.3.3 scikit-learn-0.24.2 seaborn-0.10.1 toml-0.10.2

# %%
python -m bamboolib install_nbextensions
# Out:
#   File "<ipython-input-3-83f50fa25e02>", line 1
#     python -m bamboolib install_nbextensions
#                       ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import bamboolib as bam
df = pd.read_csv("https://gist.githubusercontent.com/jwalsh/ce1dc0436aba5b7a5c9666f47fa5a380/raw/5ce3854392b43ff97907112d344fc008229b0445/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5829aa27ef6f> in <module>()
#       1 import pandas as pd
# ----> 2 import bamboolib as bam
#       3 #df = pd.read_csv("https://gist.githubusercontent.com/jwalsh/ce1dc0436aba5b7a5c9666f47fa5a380/raw/5ce3854392b43ff97907112d344fc008229b0445/titanic.csv")
#
# ModuleNotFoundError: No module named 'bamboolib'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# 3             Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                              Mr. William Henry    male  35.0      0      0
# ..                                           ...     ...   ...    ...    ...
# 151                   Mrs. Thomas (Edith Wearne)  female  22.0      1      0
# 152                                  Mr. Alfonzo    male  55.5      0      0
# 153                            Mr. Austin Blyler    male  40.5      0      2
# 154                               Mr. Ole Martin    male   NaN      0      0
# 155                            Mr. Charles Duane    male  51.0      0      1
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 4              373450   8.0500   NaN        S
# ..                ...      ...   ...      ...
# 151            113776  66.6000    C2        S
# 152        A.5. 11206   8.0500   NaN        S
# 153          A/5. 851  14.5000   NaN        S
# 154         Fa 265302   7.3125   NaN        S
# 155          PC 17597  61.3792   NaN        C
#
# [156 rows x 13 columns]
